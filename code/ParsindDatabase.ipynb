# %% [markdown]
# # LDATA 2010 - Information Visualisation
#
# # Project  : Glioblastoma Gene Interaction

# %% [markdown]
# #### Group B : Ndamtang Manuelle, Thoen Florian

# %% [markdown]
# ## Imports et installs

# %%
import matplotlib.cm as cm
import networkx as nx
import community as community_louvain
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading DataFrame

# %%
# reading the CSV file
dataframe= pd.read_table('BIOGRID-PROJECT-glioblastoma_project-GENES.projectindex.csv')

# displaying the contents of the CSV file
print(dataframe)

# reading the CSV file
dataframe2= pd.read_table('BIOGRID-PROJECT-glioblastoma_project-INTERACTIONS.tab3.csv')

# displaying the contents of the CSV file
print(dataframe2)
# Out:
#      #BIOGRID ID  ENTREZ GENE ID       SYSTEMATIC NAME OFFICIAL SYMBOL  \
# 0         108621            2335                     -             FN1
# 1         108997            2735                     -            GLI1
# 2         109355            3110                     -            MNX1
# 3         111308            5290                     -          PIK3CA
# 4         111632            5651                     -        TMPRSS15
# ..           ...             ...                   ...             ...
# 193       123785           83872           GS1-174L6.1           HMCN1
# 194       128548          219493                     -          OR5AR1
# 195       128542          219473                     -           OR8K3
# 196       125712          121227  UNQ287/PRO326/PRO335           LRIG3
# 197       126514          138474                     -           TAF1L
#
#                                       SYNONYMS  ORGANISM ID ORGANISM NAME  \
# 0     CIG|ED-B|FINC|FN|FNZ|GFND|GFND2|LETS|MSF         9606  Homo sapiens
# 1                                          GLI         9606  Homo sapiens
# 2                       HB9|HLXB9|HOXHB9|SCRA1         9606  Homo sapiens
# 3    CLOVE|CWS5|MCAP|MCM|MCMTC|PI3K|p110-alpha         9606  Homo sapiens
# 4                                   ENTK|PRSS7         9606  Homo sapiens
# ..                                         ...          ...           ...
# 193                   ARMD1|FBLN6|FIBL-6|FIBL6         9606  Homo sapiens
# 194                                   OR11-209         9606  Homo sapiens
# 195                                   OR11-181         9606  Homo sapiens
# 196                                       LIG3         9606  Homo sapiens
# 197                                     TAF2A2         9606  Homo sapiens
#
#      INTERACTION COUNT  PTM COUNT  CHEMICAL INTERACTION COUNT  ...  \
# 0                  869         32                           1  ...
# 1                  195          1                           0  ...
# 2                    7          5                           0  ...
# 3                  227         10                           2  ...
# 4                    2          0                           0  ...
# ..                 ...        ...                         ...  ...
# 193                  7          1                           0  ...
# 194                  0          0                           0  ...
# 195                  0          0                           0  ...
# 196                 60          8                           0  ...
# 197                 13          5                           0  ...
#
#     CATEGORY EVIDENCE IDS CATEGORY EVIDENCE CLASSES CATEGORY EVIDENCE METHODS  \
# 0                       -                         -                         -
# 1                       -                         -                         -
# 2                       -                         -                         -
# 3                       -                         -                         -
# 4                       -                         -                         -
# ..                    ...                       ...                       ...
# 193                     -                         -                         -
# 194                     -                         -                         -
# 195                     -                         -                         -
# 196                     -                         -                         -
# 197                     -                         -                         -
#
#     SUBCATEGORY VALUES SUBCATEGORY IDS SUBCATEGORY TAGS  \
# 0             Oncogene               -                -
# 1             Oncogene               -                -
# 2             Oncogene               -                -
# 3             Oncogene               -                -
# 4                    -               -                -
# ..                 ...             ...              ...
# 193                  -               -                -
# 194                  -               -                -
# 195                  -               -                -
# 196                  -               -                -
# 197           Oncogene               -                -
#
#     SUBCATEGORY EVIDENCE VALUES SUBCATEGORY EVIDENCE IDS  \
# 0                             -                        -
# 1                             -                        -
# 2                             -                        -
# 3                             -                        -
# 4                             -                        -
# ..                          ...                      ...
# 193                           -                        -
# 194                           -                        -
# 195                           -                        -
# 196                           -                        -
# 197                           -                        -
#
#     SUBCATEGORY EVIDENCE CLASSES SUBCATEGORY EVIDENCE METHODS
# 0                              -                            -
# 1                              -                            -
# 2                              -                            -
# 3                              -                            -
# 4                              -                            -
# ..                           ...                          ...
# 193                            -                            -
# 194                            -                            -
# 195                            -                            -
# 196                            -                            -
# 197                            -                            -
#
# [198 rows x 25 columns]
# C:\Users\thoen\mambaforge\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        #BioGRID Interaction ID Entrez Gene Interactor A  \
# 0                         2424                      672
# 1                         3189                     5925
# 2                         4867                     1634
# 3                         5438                     3791
# 4                         5977                     2260
# ...                        ...                      ...
# 36495                  3196690                     6262
# 36496                  3196691                     6262
# 36497                  3196692                     6262
# 36498                  3196693                     6262
# 36499                  3196698                     7052
#
#        Entrez Gene Interactor B  BioGRID ID Interactor A  \
# 0                          2956                   107140
# 1                          1523                   111860
# 2                          1956                   108002
# 3                           308                   109992
# 4                          2224                   108551
# ...                         ...                      ...
# 36495                      3783                   112174
# 36496                       776                   112174
# 36497                     57338                   112174
# 36498                     84502                   112174
# 36499                      2335                   112910
#
#        BioGRID ID Interactor B Systematic Name Interactor A  \
# 0                       109211                            -
# 1                       107903                RP11-174I10.1
# 2                       108276                            -
# 3                       106805                            -
# 4                       108517                            -
# ...                        ...                          ...
# 36495                   109984                  RP4-626J7.1
# 36496                   107230                  RP4-626J7.1
# 36497                   121492                  RP4-626J7.1
# 36498                   124103                  RP4-626J7.1
# 36499                   108621                RP5-1054A22.2
#
#       Systematic Name Interactor B Official Symbol Interactor A  \
# 0                                -                        BRCA1
# 1                                -                          RB1
# 2                                -                          DCN
# 3                                -                          KDR
# 4                                -                        FGFR1
# ...                            ...                          ...
# 36495                            -                         RYR2
# 36496                            -                         RYR2
# 36497                            -                         RYR2
# 36498                            -                         RYR2
# 36499                            -                         TGM2
#
#       Official Symbol Interactor B  \
# 0                             MSH6
# 1                             CUX1
# 2                             EGFR
# 3                            ANXA5
# 4                             FDPS
# ...                            ...
# 36495                        KCNN4
# 36496                      CACNA1D
# 36497                         JPH3
# 36498                         JPH4
# 36499                          FN1
#
#                                    Synonyms Interactor A  ...  \
# 0      BRCAI|BRCC1|BROVCA1|FANCS|IRIS|PNCA4|PPP1R53|P...  ...
# 1                     OSRC|PPP1R130|RB|p105-Rb|pRb|pp110  ...
# 2                       CSCD|DSPG2|PG40|PGII|PGS2|SLRR1B  ...
# 3                                CD309|FLK1|VEGFR|VEGFR2  ...
# 4      BFGFR|CD331|CEK|FGFBR|FGFR-1|FLG|FLT-2|FLT2|HB...  ...
# ...                                                  ...  ...
# 36495                        ARVC2|ARVD2|RYR-2|RyR|VTSIP  ...
# 36496                        ARVC2|ARVD2|RYR-2|RyR|VTSIP  ...
# 36497                        ARVC2|ARVD2|RYR-2|RyR|VTSIP  ...
# 36498                        ARVC2|ARVD2|RYR-2|RyR|VTSIP  ...
# 36499                    G-ALPHA-h|GNAH|HEL-S-45|TG2|TGC  ...
#
#       TREMBL Accessions Interactor B  \
# 0                             Q3SWU9
# 1                             Q3LIA3
# 2                                  -
# 3                             V9HWE0
# 4                         A0A087X090
# ...                              ...
# 36495                              -
# 36496                         Q59GD8
# 36497           F8W9A3|B4DIC1|Q96HD8
# 36498                              -
# 36499    Q6N084|Q6MZF4|Q9UQS6|Q6MZM7
#
#                           REFSEQ Accessions Interactor B Ontology Term IDs  \
# 0       NP_000170|NP_001268421|NP_001268422|NP_001268423                 -
# 1      NP_001189473|NP_001189472|NP_001904|NP_0011894...                 -
# 2      NP_001333829|NP_001333828|NP_958440|NP_005219|...                 -
# 3                                              NP_001145                 -
# 4      NP_001129294|NP_001129293|NP_001995|NP_0013653...                 -
# ...                                                  ...               ...
# 36495                                          NP_002241                 -
# 36496                NP_000711|NP_001122311|NP_001122312                 -
# 36497                NP_065706|NP_001258533|NP_001258534                 -
# 36498                             NP_001139500|NP_115828                 -
# 36499  NP_473375|NP_001293059|NP_001293058|NP_0012930...                 -
#
#       Ontology Term Names Ontology Term Categories  \
# 0                       -                        -
# 1                       -                        -
# 2                       -                        -
# 3                       -                        -
# 4                       -                        -
# ...                   ...                      ...
# 36495                   -                        -
# 36496                   -                        -
# 36497                   -                        -
# 36498                   -                        -
# 36499                   -                        -
#
#        Ontology Term Qualifier IDs  Ontology Term Qualifier Names  \
# 0                                -                              -
# 1                                -                              -
# 2                                -                              -
# 3                                -                              -
# 4                                -                              -
# ...                            ...                            ...
# 36495                            -                              -
# 36496                            -                              -
# 36497                            -                              -
# 36498                            -                              -
# 36499                            -                              -
#
#       Ontology Term Types Organism Name Interactor A  \
# 0                       -               Homo sapiens
# 1                       -               Homo sapiens
# 2                       -               Homo sapiens
# 3                       -               Homo sapiens
# 4                       -               Homo sapiens
# ...                   ...                        ...
# 36495                   -               Homo sapiens
# 36496                   -               Homo sapiens
# 36497                   -               Homo sapiens
# 36498                   -               Homo sapiens
# 36499                   -               Homo sapiens
#
#       Organism Name Interactor B
# 0                   Homo sapiens
# 1                   Homo sapiens
# 2                   Homo sapiens
# 3                   Homo sapiens
# 4                   Homo sapiens
# ...                          ...
# 36495               Homo sapiens
# 36496               Homo sapiens
# 36497               Homo sapiens
# 36498               Homo sapiens
# 36499               Homo sapiens
#
# [36500 rows x 37 columns]

# %% [markdown]
# ## Function To Build Graph

# %%
def createGraph(dataframe, dataframe2):
    lenDataFrame=len(dataframe.index)
    G = nx.Graph()
    count = 0
    while count < lenDataFrame:
        first = dataframe.iat[count,3]
        G.add_node(first)
        count += 1
    label = {}
    for i in G.nodes():
        label[i] = i
    count2 = 0
    tab=G.nodes()
    lenDataFrame2=len(dataframe2.index)
    while count2 < lenDataFrame2:
        first = dataframe2.iat[count2,7]
        second = dataframe2.iat[count2,8]
        if first in tab and second in tab:
            G.add_edge(first,second)
        count2 += 1
    return G

# %% [markdown]
# ## Visualisation of the Graph

# %%
G = createGraph(dataframe,dataframe2)
plt.figure(figsize=(25,20))
plt.title('Protein Graph')
pos1 = nx.spring_layout(G,k=3,iterations= 10)
nx.draw_networkx_nodes(G,pos1,alpha=0.5)
nx.draw_networkx_edges(G,pos1, alpha=0.3)
nx.draw_networkx_labels(G,pos1,label,font_size=10)
plt.show()

# %%
#############TEST
#string = dataframe.iat[0,4]
#tableau=string.split('|')
#print(tableau)
#tab=['jdjd']
#print(tab+tableau)
# Out:
# ['CIG', 'ED-B', 'FINC', 'FN', 'FNZ', 'GFND', 'GFND2', 'LETS', 'MSF']
# ['jdjd', 'CIG', 'ED-B', 'FINC', 'FN', 'FNZ', 'GFND', 'GFND2', 'LETS', 'MSF']

# %% [markdown]
# ## Functions about the differents metrics of the Graph

# %%
def countProtein():
    G=createGraph(dataframe,dataframe2)
    return G.number_of_nodes()
def countInteractions():
    G=createGraph(dataframe,dataframe2)
    return G.number_of_edges()
def betweeness_centrality():
    G=createGraph(dataframe,dataframe2)
    return nx.betweenness_centrality(G)
def clustering_coefficient():
    G=createGraph(dataframe,dataframe2)
    return nx.clustering(G)
def MST():
    G=createGraph(dataframe,dataframe2)
    return nx.minimum_spanning_tree(G)
def shortestPath(G,source,target):
    return nx.shortest_path(G,source,target)
def communitiesDetection(G):
    partition = community_louvain.best_partition(G)
    # draw the graph
    plt.figure(figsize=(25,20))
    plt.title('Communities_Detection')
    pos = nx.spring_layout(G,k=3, iterations=10)
    # color the nodes according to their partition
    cmap = cm.get_cmap('plasma', max(partition.values()) + 1)
    nx.draw_networkx_nodes(G, pos, partition.keys(), node_size=90,cmap=cmap, node_color=list(partition.values()))
    nx.draw_networkx_edges(G, pos, alpha=0.3,label=True)
    nx.draw_networkx_labels(G,pos,label,font_size=10)
    plt.show()
#def numberOfCommunities(G)

# %%
######## TEST COMMU DETECTION
communitiesDetection(G)

# %%
########TEST AFFICHAGE MINIMUM SPANNING TREE
G=MST()
plt.figure(figsize=(25,20))
plt.title('Protein Graph')
pos1 = nx.spring_layout(G,k=3,iterations= 10)
nx.draw_networkx_nodes(G,pos1,alpha=0.3)
nx.draw_networkx_edges(G,pos1, alpha=0.3)
nx.draw_networkx_labels(G,pos1,label,font_size=10)
plt.show()

# %%
G=createGraph(dataframe,dataframe2)
x=nx.adjacency_matrix(G)
print(x)
# Out:
#   (0, 33)	1
#   (0, 59)	1
#   (0, 75)	1
#   (0, 85)	1
#   (0, 93)	1
#   (0, 106)	1
#   (0, 120)	1
#   (0, 141)	1
#   (0, 149)	1
#   (0, 151)	1
#   (0, 159)	1
#   (1, 140)	1
#   (1, 188)	1
#   (3, 27)	1
#   (3, 29)	1
#   (3, 33)	1
#   (3, 77)	1
#   (3, 85)	1
#   (3, 134)	1
#   (3, 166)	1
#   (6, 110)	1
#   (7, 7)	1
#   (7, 12)	1
#   (7, 21)	1
#   (7, 95)	1
#   :	:
#   (188, 30)	1
#   (188, 33)	1
#   (188, 77)	1
#   (188, 101)	1
#   (188, 106)	1
#   (188, 119)	1
#   (188, 131)	1
#   (188, 134)	1
#   (188, 140)	1
#   (188, 149)	1
#   (188, 153)	1
#   (188, 154)	1
#   (188, 176)	1
#   (188, 188)	1
#   (189, 25)	1
#   (189, 32)	1
#   (189, 33)	1
#   (189, 85)	1
#   (189, 95)	1
#   (190, 85)	1
#   (191, 40)	1
#   (191, 137)	1
#   (191, 191)	1
#   (196, 77)	1
#   (196, 85)	1
